# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Load January data
df_jan = pd.read_parquet('/home/nwoke/Documents/git_cloned/Github/mlops_101/week1/data/fhv_tripdata_2021-01.parquet')
df_jan
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 2                     B00013 2021-01-01 00:01:00 2021-01-01 01:51:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number
# 0                 NaN           NaN    None                 B00009
# ...

# %%
df_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154112 entries, 0 to 1154111
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   dispatching_base_num    1154112 non-null  object
#  1   pickup_datetime         1154112 non-null  datetime64[ns]
#  2   dropOff_datetime        1154112 non-null  datetime64[ns]
#  3   PUlocationID            195845 non-null   float64
#  4   DOlocationID            991892 non-null   float64
#  5   SR_Flag                 0 non-null        object
#  6   Affiliated_base_number  1153227 non-null  object
# dtypes: datetime64[ns](2), float64(2), object(3)
# memory usage: 61.6+ MB

# %%
# get the total time of the trip  by taking the time difference
df_jan["duration"] = df_jan["dropOff_datetime"] - df_jan["pickup_datetime"]

# %%
# convert the time duration from days to minutes format
df_jan["duration"] = df_jan["duration"].apply(lambda dur:dur.total_seconds()/60)
df_jan
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 2                     B00013 2021-01-01 00:01:00 2021-01-01 01:51:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number    duration
# ...

# %%
df_jan.describe()
# Out:
#         PUlocationID   DOlocationID      duration
# count  195845.000000  991892.000000  1.154112e+06
# mean      139.859690     135.898030  1.916722e+01
# std        74.991382      80.474902  3.986922e+02
# min         1.000000       1.000000  1.666667e-02
# 25%        75.000000      67.000000  7.766667e+00
# 50%       143.000000     132.000000  1.340000e+01
# 75%       206.000000     213.000000  2.228333e+01
# max       265.000000     265.000000  4.233710e+05

# %%
# filter the dataset based on duration (in mins)
df_jan = df_jan[(df_jan["duration"]>1)&(df_jan["duration"]<=60)]
df_jan
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# 5                     B00037 2021-01-01 00:59:02 2021-01-01 01:08:05
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number   duration
# ...

# %%
# df_jan[(df_jan["PUlocationID"].isna())]

# %%
# df_jan[(df_jan["DOlocationID"].isna())]

# %%
# replace Nan value in some columns with value -1  
# df_jan[["PUlocationID", "DOlocationID"]].replace(to_replace = "NaN", value = -1, inplace = True) 
df_jan[["PUlocationID", "DOlocationID"]] = df_jan[["PUlocationID", "DOlocationID"]].fillna(-1)
# df[['col1', 'col2']] = df[['col1','col2']].fillna('')
df_jan
# Out:
# /home/nwoke/.local/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# 5                     B00037 2021-01-01 00:59:02 2021-01-01 01:08:05
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# ...

# %%
((df_jan["PUlocationID"].values == -1).mean()) * 100
# Out:
# 83.54190613998314

# %%
((df_jan["DOlocationID"].values == -1).mean()) * 100
# Out:
# 13.313679617383622

# %%
df_jan
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 0                     B00009 2021-01-01 00:27:00 2021-01-01 00:44:00
# 1                     B00009 2021-01-01 00:50:00 2021-01-01 01:07:00
# 3                     B00037 2021-01-01 00:13:09 2021-01-01 00:21:26
# 4                     B00037 2021-01-01 00:38:31 2021-01-01 00:53:44
# 5                     B00037 2021-01-01 00:59:02 2021-01-01 01:08:05
# ...                      ...                 ...                 ...
# 1154107               B03266 2021-01-31 23:43:03 2021-01-31 23:51:48
# 1154108               B03284 2021-01-31 23:50:27 2021-02-01 00:48:03
# 1154109      B03285          2021-01-31 23:13:46 2021-01-31 23:29:58
# 1154110      B03285          2021-01-31 23:58:03 2021-02-01 00:17:29
# 1154111               B03321 2021-01-31 23:39:00 2021-02-01 00:15:00
#
#          PUlocationID  DOlocationID SR_Flag Affiliated_base_number   duration
# ...

# %%
categorical = ["PUlocationID", "DOlocationID"]
df_jan[categorical] = df_jan[categorical].astype(str)
# Out:
# /home/nwoke/.local/lib/python3.8/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
train_dicts = df_jan[categorical].to_dict(orient="records")
train_dicts
# Out:
# [{'PUlocationID': 'nan', 'DOlocationID': 'nan'},
#  {'PUlocationID': 'nan', 'DOlocationID': 'nan'},
#  {'PUlocationID': 'nan', 'DOlocationID': '72.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '61.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '71.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '91.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '39.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '37.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '39.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '72.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '72.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '89.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '177.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '225.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '63.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '67.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '22.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '61.0'},
#  {'PUlocationID': 'nan', 'DOlocationID': '14.0'},
# ...

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <1109205x525 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2218410 stored elements in Compressed Sparse Row format>

# %%
y_train = df_jan["duration"].values
y_train
# Out:
# array([17.        , 17.        ,  8.28333333, ..., 16.2       ,
#        19.43333333, 36.        ])

# %%
lr =  LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 10.523282800783907
